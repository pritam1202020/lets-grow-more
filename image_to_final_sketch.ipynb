# %%
#Step-1:  Importing required libraries
from google.colab.patches import cv2_imshow

import cv2

# %%
#Step-2:  Loading the image
img = cv2.imread('doll.jpg', 1)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=533x800 at 0x7F608359C590>

# %%
#Step-3: Converting an image into gray_scale image
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=533x800 at 0x7F6081CCE490>
# -1

# %%
#Step-4: Inverting the image
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=533x800 at 0x7F6081C59290>

# %%
#Step-5: Smoothing the image 
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=533x800 at 0x7F6081CCE850>

# %%
#Step-6: Obtaining the final sketch
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
#Final Output as Pencil Sketch
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=533x800 at 0x7F6081C57750>
